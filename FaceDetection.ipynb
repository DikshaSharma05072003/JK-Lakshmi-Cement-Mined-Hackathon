# %%
import cv2
import sys

# Get user supplied values
imagePath = input("Enter the image name: ")+'.jpg'
cascPath = "haarcascade_frontalface_default.xml"

# Create the haar cascade
faceCascade = cv2.CascadeClassifier(cascPath)

# Read the image
image = cv2.imread(imagePath)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Detect faces in the image
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30),
    flags = cv2.CASCADE_SCALE_IMAGE
)

print("Found {0} faces!".format(len(faces)))

# Draw a rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)

cv2.imshow("Faces found", image)
cv2.waitKey(0)
# Out:
# Enter the image name: 28.jpg
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-aa040d24c67d> in <module>
#      11 # Read the image
#      12 image = cv2.imread(imagePath)
# ---> 13 gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#      14
#      15 # Detect faces in the image
#
# error: OpenCV(4.6.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
import cv2

print("If you want to exit the video/webcam, enter 'q'.\n")

print("Enter 1 to open a webcam.")
print("Enter 2 to open a video.")
opt =int(input("Enter your choice: "))
if opt==1:
    vidpath =0
else:
    vidpath = input("Enter the video name: ")+'.mp4' 

cap = cv2.VideoCapture(vidpath)

# Create the haar cascade
faceCascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

while(True):
	# Capture frame-by-frame
	ret, frame = cap.read()

	# Our operations on the frame come here
	gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

	# Detect faces in the image
	faces = faceCascade.detectMultiScale(
		gray,
		scaleFactor=1.35,
		minNeighbors=5,
		minSize=(30, 30)
	)

	print("Found {0} faces!".format(len(faces)))

	# Draw a rectangle around the faces
	for (x, y, w, h) in faces:
		cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)


	# Display the resulting frame
	cv2.imshow('frame', frame)
	if cv2.waitKey(1) & 0xFF == ord('q'):
		break

# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()
# Out:
# If you want to exit the video/webcam, enter 'q'.
#
# Enter 1 to open a webcam.
# Enter 2 to open a video.
# Enter your choice: 1
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-6f99c1276ce7> in <module>
#      21
#      22         # Our operations on the frame come here
# ---> 23         gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#      24
#      25         # Detect faces in the image
#
# error: OpenCV(4.6.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
import cv2
import sys
from google.colab.patches import cv2_imshow
import math
# Get user supplied values
imagePath = input("Enter the image name: ")+'.jpeg'
cascPath = "haarcascade_frontalface_default.xml"

# Create the haar cascade
faceCascade = cv2.CascadeClassifier("/content/haarcascade_frontalface_default.xml")

# Read the image
image = cv2.imread("/content/Screenshot 2023-03-04 at 7.09.38 PM.png")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Detect faces in the image
faces = faceCascade.detectMultiScale(gray,scaleFactor=1.2,minNeighbors=5,minSize=(30, 30),flags = cv2.CASCADE_SCALE_IMAGE
)

print("Found {0} faces!".format(len(faces)))

# Draw a rectangle around the faces
for (x, y, w, h) in faces:  
    cv2.rectangle(image, (x, y), (x+w, y+h), (255, 0, 0), 2)
    crop=image[x:y,x+w:y+h]
    

cv2_imshow(image)
cv2.waitKey(0)
# Out:
# Enter the image name: 1
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-31fed6ed43d4> in <module>
#      12 # Read the image
#      13 image = cv2.imread("/content/Screenshot 2023-03-04 at 7.09.38 PM.png")
# ---> 14 gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#      15
#      16 # Detect faces in the image
#
# error: OpenCV(4.6.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %% [markdown]
# #color =blue
# import tkinter as t
# from tkinter import *
# from PIL import Image,ImageTk
#
# window=Tk()
# window.title("Face Recognition")
# window.geometry("500x500")
#
# window.configure(bg="white")
# w=t.Label(window,text="Face Recognition System")
# w.pack()
# def image():
#     img = cv2.imread('blog1.jpeg')
#     cv2.imwrite('savedimage.jpeg', img)
# def video():
#     print("video")
# def openFile():
#     canvas= Canvas(window, width= 600, height= 400)
#     canvas.pack()
#
#     img= t.PhotoImage(Image.open("/Users/dp/Downloads/blog1.jpeg"))
#     canvas.create_image(10,10,anchor=NW,image=img)
#
# button = t.Button(window,text="Image", fg="red",command=image)
# button2=t.Button(window,text="Video",fg="red", command=video)
# button3=t.Button(window,text="hello",fg="red",command=openFile)
# button.pack()
# button2.pack()
# button3.pack()
# window.mainloop()
